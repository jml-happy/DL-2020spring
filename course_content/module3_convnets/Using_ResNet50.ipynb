# %% [markdown]
# <a href="https://colab.research.google.com/github/badriadhikari/2019-Spring-DL/blob/master/course_content/module3_convnets/Using_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='resnet50.png')
from google.colab import files
files.download('resnet50.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ae0afaaf-1a24-46fa-8532-b6afe53b27fb" name="files[]" multiple disabled />
#      <output id="result-ae0afaaf-1a24-46fa-8532-b6afe53b27fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpeg to cat.jpeg

# %%
img_path = 'cat.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
# Out:
# ...
# 40960/35363 [==================================] - 0s 2us/step
# Predicted: [('n02124075', 'Egyptian_cat', 0.60777086), ('n02123045', 'tabby', 0.2586879), ('n02123159', 'tiger_cat', 0.09364624)]

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02124075', 'Egyptian_cat', 0.60777086), ('n02123045', 'tabby', 0.2586879), ('n02123159', 'tiger_cat', 0.09364624)]
